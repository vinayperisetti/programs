# %%
import matplotlib.pyplot as plt
import numpy as np
x=[0,2]
y=[0,100]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[1,2,3,4,5]
y=[10,20,30,40,50]
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[1,2,6]
y=[3,8,1]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=[3,8,1,10,5,7]
plt.plot(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=[3,8,1,10,5,7]
plt.plot(y,color='g',marker='*')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
y=np.array([35,50,15])
plt.pie(y)
plt.show()

# %%
plt.pie(y,labels=["A","B","C"])
plt.legend()
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt
x=[1,2,4,6]
y=[7,8,1,10]
plt.bar(x,y)
plt.show()

# %%
plt.barh(x,y)
plt.show()
