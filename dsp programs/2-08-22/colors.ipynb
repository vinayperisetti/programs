# %%
import matplotlib.pyplot as plt
import numpy as np
x=[0,1,1,2,2,3]
y=[0,1,2,1,2,3]
colors=['red','blue','green','yellow','orange','cyan']
plt.scatter(x,y,c=colors)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[0,1,1,2,2,3]
y=[0,1,2,1,2,3]
colors=['red','blue','green','yellow','orange','cyan']
plt.scatter(x,y,c=colors,s=200)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[0,1,1,2,2,3]
y=[0,1,2,1,2,3]
colors=['red','blue','green','yellow','orange','cyan']
plt.scatter(x,y,c=colors,marker="<")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[0,1,1,2,2,3]
y=[0,1,2,1,2,3]
colors=['red','blue','green','yellow','orange','cyan']
plt.scatter(x,y,c=colors,marker='1',s=200)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[0,1,1,2,2,3]
y=[0,1,2,1,2,3]
colors=['red','blue','green','yellow','orange','cyan']
plt.scatter(x,y,c=colors,marker='>',s=200)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
data=[10,20,40,50,70]
plt.boxplot(data)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.rand(40)
y=np.random.rand(40)
z=np.random.rand(40)
colors=np.random.rand(40)
plt.scatter(x,y,s=2*100,c=colors,alpha=0.5)
plt.show()
