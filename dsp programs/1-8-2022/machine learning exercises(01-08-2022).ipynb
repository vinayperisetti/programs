# %%
import pandas as pd
data=pd.read_csv("bollywood.csv")
print(data)
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS     Action
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SlNo                 149 non-null    int64
#  1   Release Date         149 non-null    object
#  2   MovieName            149 non-null    object
#  3   ReleaseTime          149 non-null    object
#  4   Genre                149 non-null    object
#  5   Budget               149 non-null    int64
#  6   BoxOfficeCollection  149 non-null    float64
#  7   YoutubeViews         149 non-null    int64
#  8   YoutubeLikes         149 non-null    int64
#  9   YoutubeDislikes      149 non-null    int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 11.8+ KB

# %%
data.describe()
# Out:
#              SlNo      Budget  BoxOfficeCollection  YoutubeViews  \
# count  149.000000  149.000000           149.000000  1.490000e+02
# mean    75.000000   29.442953            55.667248  3.337920e+06
# std     43.156691   28.237981            94.494531  3.504407e+06
# min      1.000000    2.000000             0.010000  4.354000e+03
# 25%     38.000000   11.000000             8.780000  1.076591e+06
# 50%     75.000000   21.000000            28.000000  2.375050e+06
# 75%    112.000000   35.000000            57.450000  4.550051e+06
# max    149.000000  150.000000           735.000000  2.317107e+07
#
#         YoutubeLikes  YoutubeDislikes
# count     149.000000       149.000000
# mean     7877.536913      1207.818792
# std     12748.047191      1852.692938
# min         1.000000         1.000000
# 25%      1377.000000       189.000000
# 50%      4111.000000       614.000000
# 75%      9100.000000      1419.000000
# max    101275.000000     11888.000000

# %%
data.max()
# Out:
# SlNo                               149
# Release Date                  9-May-14
# MovieName              Zilla Ghaziabad
# ReleaseTime                          N
# Genre                        Thriller
# Budget                             150
# BoxOfficeCollection              735.0
# YoutubeViews                  23171067
# YoutubeLikes                    101275
# YoutubeDislikes                  11888
# dtype: object

# %%
data.min()
# Out:
# SlNo                          1
# Release Date           1-Feb-13
# MovieName              2 States
# ReleaseTime                  FS
# Genre                    Drama
# Budget                        2
# BoxOfficeCollection        0.01
# YoutubeViews               4354
# YoutubeLikes                  1
# YoutubeDislikes               1
# dtype: object

# %%
data.isnull()
# Out:
#       SlNo  Release Date  MovieName  ReleaseTime  Genre  Budget  \
# 0    False         False      False        False  False   False
# 1    False         False      False        False  False   False
# 2    False         False      False        False  False   False
# 3    False         False      False        False  False   False
# 4    False         False      False        False  False   False
# ..     ...           ...        ...          ...    ...     ...
# 144  False         False      False        False  False   False
# 145  False         False      False        False  False   False
# 146  False         False      False        False  False   False
# 147  False         False      False        False  False   False
# 148  False         False      False        False  False   False
#
#      BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 0                  False         False         False            False
# ...

# %%
data.head()
# Out:
#    SlNo Release Date           MovieName ReleaseTime      Genre  Budget  \
# 0     1    18-Apr-14            2 States          LW    Romance      36
# 1     2     4-Jan-13        Table No. 21           N  Thriller       10
# 2     3    18-Jul-14  Amit Sahni Ki List           N     Comedy      10
# 3     4     4-Jan-13    Rajdhani Express           N     Drama        7
# 4     5     4-Jul-14        Bobby Jasoos           N     Comedy      18
#
#    BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 0               104.00       8576361         26622             2527
# 1                12.00       1087320          1129              137
# 2                 4.00        572336           586               54
# 3                 0.35         42626            86               19
# 4                10.80       3113427          4512             1224

# %%
data.tail()
# Out:
#      SlNo Release Date                    MovieName ReleaseTime     Genre  \
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N    Comedy
# 145   146    13-Mar-15                         NH10           N  Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N    Comedy
# 147   148    20-Mar-15                     Hunterrr           N    Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS    Action
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 144      15                30.00       3250917          8185              615
# 145      13                32.10       5592977         15464             1513
# 146      32                12.00       2316047          4289              807
# 147       5                11.89       4674795          3706              762
# 148     150               120.00       4740727         13466             2649

# %%
data["Genre"]
# Out:
# 0        Romance
# 1      Thriller
# 2         Comedy
# 3         Drama
# 4         Comedy
#          ...
# 144       Comedy
# 145     Thriller
# 146       Comedy
# 147       Comedy
# 148       Action
# Name: Genre, Length: 149, dtype: object

# %%
#How many movies got released in each genre? Which genre had highest number of releases? Sort 
#number of releases in each genre in descending order.
data.Genre.value_counts()
# Out:
# Comedy       36
#  Drama       35
# Thriller     26
# Romance      25
# Action       21
# Thriller      3
# Action        3
# Name: Genre, dtype: int64

# %%
#How many movies in each genre got released in different release times like long weekend, festive 
#season, etc. (Note: Do a cross tabulation between Genre and ReleaseTime.)
pd.crosstab(data["Genre"],data["ReleaseTime"])
# Out:
# ReleaseTime  FS  HS  LW   N
# Genre
#  Drama        4   6   1  24
# Action        3   3   3  12
# Action        0   0   0   3
# Comedy        3   5   5  23
# Romance       3   3   4  15
# Thriller      4   1   1  20
# Thriller      0   0   1   2

# %%
data.loc[data["Budget"]>25]
# Out:
#      SlNo Release Date                    MovieName ReleaseTime    Genre  \
# 0       1    18-Apr-14                     2 States          LW  Romance
# 6       7    19-Sep-14                Daawat-E-Ishq           N   Comedy
# 7       8    11-Jan-13   Matru Ki Bijlee Ka Mandola           N   Comedy
# 8       9    10-Jan-14                 Dedh Ishqiya          LW   Comedy
# 10     11    28-Mar-14                  Dishkiyaoon           N  Action
# ..    ...          ...                          ...         ...      ...
# 138   139    23-Jan-15                         Baby           N   Action
# 141   142     6-Feb-15                    Shamitabh           N   Drama
# 142   143    13-Feb-15                          Roy          FS  Romance
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N   Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS   Action
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# ...

# %%
data['ROI'] = data['BoxOfficeCollection']-data['Budget']/data['Budget']
data[['BoxOfficeCollection','Budget','ROI']].nlargest(10,['ROI'])
# Out:
#      BoxOfficeCollection  Budget    ROI
# 89                 735.0      85  734.0
# 115                395.0      75  394.0
# 26                 383.0     125  382.0
# 43                 377.0     100  376.0
# 92                 340.0     140  339.0
# 82                 311.0      70  310.0
# 119                300.0     115  299.0
# 132                298.0      35  297.0
# 78                 200.0      90  199.0
# 101                164.0      30  163.0

# %%
import matplotlib.pyplot as plt 
import seaborn as sn
# %matplotlib inline

# %%
plt.hist(data['Budget']);

# %%
sn.distplot(data['Budget'])
# Out:
# C:\Users\vinay\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Budget', ylabel='Density'>

# %%
data.describe()
# Out:
#              SlNo      Budget  BoxOfficeCollection  YoutubeViews  \
# count  149.000000  149.000000           149.000000  1.490000e+02
# mean    75.000000   29.442953            55.667248  3.337920e+06
# std     43.156691   28.237981            94.494531  3.504407e+06
# min      1.000000    2.000000             0.010000  4.354000e+03
# 25%     38.000000   11.000000             8.780000  1.076591e+06
# 50%     75.000000   21.000000            28.000000  2.375050e+06
# 75%    112.000000   35.000000            57.450000  4.550051e+06
# max    149.000000  150.000000           735.000000  2.317107e+07
#
#         YoutubeLikes  YoutubeDislikes
# count     149.000000       149.000000
# mean     7877.536913      1207.818792
# std     12748.047191      1852.692938
# min         1.000000         1.000000
# 25%      1377.000000       189.000000
# 50%      4111.000000       614.000000
# 75%      9100.000000      1419.000000
# max    101275.000000     11888.000000

# %%
import datetime

# %%
data['Release Date']=pd.to_datetime(data['Release Date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SlNo                 149 non-null    int64
#  1   Release Date         149 non-null    datetime64[ns]
#  2   MovieName            149 non-null    object
#  3   ReleaseTime          149 non-null    object
#  4   Genre                149 non-null    object
#  5   Budget               149 non-null    int64
#  6   BoxOfficeCollection  149 non-null    float64
#  7   YoutubeViews         149 non-null    int64
#  8   YoutubeLikes         149 non-null    int64
#  9   YoutubeDislikes      149 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(3)
# memory usage: 11.8+ KB

# %%
data.min()
# Out:
# SlNo                                     1
# Release Date           2013-01-04 00:00:00
# MovieName                         2 States
# ReleaseTime                             FS
# Genre                               Drama
# Budget                                   2
# BoxOfficeCollection                   0.01
# YoutubeViews                          4354
# YoutubeLikes                             1
# YoutubeDislikes                          1
# dtype: object

# %%
data['month']=data['Release Date'].apply(lambda x:x.month_name())
data['year']=data['Release Date'].apply(lambda x:x.year)

# %%
data.head()
# Out:
#    SlNo Release Date           MovieName ReleaseTime      Genre  Budget  \
# 0     1   2014-04-18            2 States          LW    Romance      36
# 1     2   2013-01-04        Table No. 21           N  Thriller       10
# 2     3   2014-07-18  Amit Sahni Ki List           N     Comedy      10
# 3     4   2013-01-04    Rajdhani Express           N     Drama        7
# 4     5   2014-07-04        Bobby Jasoos           N     Comedy      18
#
#    BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes    month  \
# 0               104.00       8576361         26622             2527    April
# 1                12.00       1087320          1129              137  January
# 2                 4.00        572336           586               54     July
# 3                 0.35         42626            86               19  January
# 4                10.80       3113427          4512             1224     July
#
#    year
# 0  2014
# 1  2013
# 2  2014
# 3  2013
# 4  2014

# %%
a=pd.crosstab(data['month'],data['year'])

# %%
a
# Out:
# year       2013  2014  2015
# month
# April         5     6     0
# August        4     4     0
# December      0     2     0
# February      6     6     4
# January       8     7     5
# July          9     7     0
# June          5     5     0
# March         8     8     3
# May           6    12     0
# November      5     5     0
# October       6     3     0
# September     5     5     0

# %%
a.value_counts()
# Out:
# 2013  2014  2015
# 5     5     0       3
# 0     2     0       1
# 4     4     0       1
# 5     6     0       1
# 6     3     0       1
#       6     4       1
#       12    0       1
# 8     7     5       1
#       8     3       1
# 9     7     0       1
# dtype: int64

# %%
data.sample(31)
# Out:
#      SlNo Release Date                         MovieName ReleaseTime  \
# 86     87   2014-03-28                       Youngistaan           N
# 24     25   2014-11-21                      Happy Ending           N
# 44     45   2013-03-15                                3G           N
# 8       9   2014-01-10                      Dedh Ishqiya          LW
# 67     68   2014-05-02                      Purani Jeans          HS
# 117   118   2013-08-23                       Madras Cafe           N
# 48     49   2014-05-09                      Koyelaanchal          HS
# 110   111   2014-02-07                  Hasee To Phansee           N
# 78     79   2014-08-15                   Singham Returns          LW
# 122   123   2013-11-15                             Rajjo          FS
# 42     43   2014-09-19                        Khoobsurat           N
# 35     36   2013-02-22                   Zilla Ghaziabad           N
# 81     82   2014-11-28                             Ungli           N
# ...

# %%
data['ROI']=data['BoxOfficeCollection']-data['Budget']/data['Budget']

# %%
k=data['ROI']

# %%
k
# Out:
# 0      103.00
# 1       11.00
# 2        3.00
# 3       -0.65
# 4        9.80
#         ...
# 144     29.00
# 145     31.10
# 146     11.00
# 147     10.89
# 148    119.00
# Name: ROI, Length: 149, dtype: float64

# %%
m=k.sort_values()[-9:]

# %%
m
# Out:
# 78     199.0
# 132    297.0
# 119    299.0
# 82     310.0
# 92     339.0
# 43     376.0
# 26     382.0
# 115    394.0
# 89     734.0
# Name: ROI, dtype: float64

# %%
j=m.index

# %%
for i in j:
    print(data.loc[i,"MovieName"])
# Out:
# Singham Returns
# Grand Masti
# Krrish 3
# Yeh Jawaani Hai Deewani
# Bang Bang
# Kick
# Happy New Year
# Chennai Express
# PK
